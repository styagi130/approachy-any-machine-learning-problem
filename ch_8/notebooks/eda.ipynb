# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from nltk.tokenize import word_tokenize

# %%
import pathlib
import sys
from collections import Counter
sys.path.append("./../")

from src.utils import io

# %%
config_filepath = pathlib.Path("/home/kwantics/python3-tasks/torchCodes/india_mart-spam_nonSpam/configs/config_imart_lstm.yml")
config = io.load_config(config_filepath)

# %%
df = pd.read_csv(config.train_filepath, usecols=config.data["columns"])

# %%
df.head()
# Out:
#                                                 text  tagInt
# 0   sir hello good after noon mera naam vivek hai...       1
# 1   hello hello surya sells corporation haan ji h...       1
# 2   hello hello haan ji hello good afternoon sir ...       0
# 3   hello hello haan ji namskar ji kaha se bol ra...       1
# 4   hello two hello hello sir hello hello hello h...       1

# %%
total_tokens_counter = Counter([word for sent in df.loc[:, "text"].values for word in sent.split()])

# %% [markdown]
# ## Visualize input_distributions

# %%
df.loc[:, "num_tokens"] = df.loc[:, "text"].apply(lambda x: len(x.split()))
df.groupby("tagInt").hist(bins=200)
# Out:
# tagInt
# 0    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# 1    [[AxesSubplot(0.125,0.125;0.775x0.755)]]
# dtype: object
